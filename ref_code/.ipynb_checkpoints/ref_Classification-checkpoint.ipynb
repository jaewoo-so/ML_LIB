# %%
import sys
sys.path.append(r'E:\01_PProj\ML_LIB')

import Lib_sjw.training as tr
import Lib_sjw.model_interface as mi
import Lib_sjw.model_parmas as mp
import Lib_sjw.evaluator as ev
import Lib_sjw.classification_util as cu


from sklearn.datasets import load_boston , load_iris , load_breast_cancer
from sklearn.metrics import mean_squared_error , roc_auc_score , precision_score
from sklearn.model_selection import train_test_split
import numpy as np

from collections import OrderedDict

# %%
def Test_Classification(xtrain , xtest , ytrain , nfold = 5 , verbose = False):
    # name list 
    name_list = ['xgb',
                 'lgb',
                 'cat',
                 'rfc',
                 'svm',
                 'gpc',
                 'lda',
                 'qda']
    # model_list , param_list , 
    model_list = OrderedDict()    
    model_list['xgb']  = mi.myXGBClassifier()
    model_list['lgb']  = mi.myLGBMClassifier()
    model_list['cat']  = mi.myCatBoostClassifier()
    model_list['rfc']  = mi.myRandomForestClassifier()
    
    model_list['svm']  = mi.mySVMClassifier()
    model_list['gpc']  = mi.myGPClassifier()
    model_list['lda']  = mi.myLDAClassifier()
    model_list['qda']  = mi.myQDAClassifier()
    
    param_list = OrderedDict()
    param_list['xgb'] = mp.param_xgb('classification' , len(np.unique(y)), use_gpu= False)
    param_list['lgb'] = mp.param_lgbm('classification' , len(np.unique(y)), use_gpu= False)
    param_list['cat']  = mp.param_cat('classification' , use_gpu= True , is_unbalance= False )
    param_list['rfc']  = mp.param_rf('classification')
    param_list['svm']  = mp.param_svm('classification')
    param_list['gpc']  = mp.param_gpc('classification')
    param_list['lda']  = mp.param_lda()
    param_list['qda']  = mp.param_qda()
    
    #fitting parmas
    fitpm_list = OrderedDict()

    for name in name_list:
            fitpm_list[name] = {}
    fitpm_list['lgb'] = {'early_stopping_rounds' : 12 , 'verbose' : -1}
    #fit_cat = {}
    #fit_xgb = {}
    
    # metric func
    metric_func = cu.aucpr
    
    # Result
    result_list = OrderedDict()

    # Training 
    for name in name_list:
        print(name)
        fold_predict , fold_oof , fold_metric , fold_model = tr.training_fixedTest('classification' , model_list[name] , param_list[name] , fitpm_list[name] ,  metric_func , xtrain , ytrain , xtest , 5  ) 
        result_list[name] = [fold_predict , fold_oof , fold_metric]
    print('Test_Classification Complete')

def Test_Classification_TestFold(X , y , nfold_test , nfold_val , verbose = True):
    # name list 
    name_list = ['xgb',
                 'lgb',
                 'cat',
                 'rfc',
                 'svm',
                 'gpc',            
                 'lda',
                 'qda']
    # model_list , param_list , 
    model_dict = OrderedDict()    
    model_dict['xgb']  = mi.myXGBClassifier()
    model_dict['lgb']  = mi.myLGBMClassifier()
    model_dict['cat']  = mi.myCatBoostClassifier()
    model_dict['rfc']  = mi.myRandomForestClassifier()
    model_dict['svm']  = mi.mySVMClassifier()
    model_dict['gpc']  = mi.myGPClassifier()
    model_dict['lda']  = mi.myLDAClassifier()
    model_dict['qda']  = mi.myQDAClassifier()
    
    param_list = OrderedDict ( )
    param_list['xgb'] = mp .param_xgb ('classification' , len(np.unique(y)) , use_gpu= False )
    param_list['lgb'] = mp .param_lgbm('classification' , len(np.unique(y)) , use_gpu= False )
    param_list['cat'] = mp .param_cat ('classification' , use_gpu= True , is_unbalance= False )
    param_list['rfc'] = mp .param_rf ('classification' )
    param_list['svm'] = mp .param_svm ('classification' )
    param_list['gpc'] = mp .param_gpc ('classification' )
    param_list['lda'] = mp .param_lda ( )
    param_list['qda'] = mp .param_qda ( )
    
    #fitting parmas
    fitpm_list = OrderedDict()
    for name in name_list:
            fitpm_list[name] = {}
    fitpm_list['lgb'] = {'early_stopping_rounds' : 12 , 'verbose' : -1}
    #fit_cat = {}
    #fit_xgb = {}
    
    # metric func
    metric_func = cu.aucpr
    
    # Result
    result_list = OrderedDict()
    auc_score_list = OrderedDict()
    for name in name_list:
        print(name)
        test_fold_index , oof, model_list = tr.training_Testfold('classification' , model_dict[name] , param_list[name] , fitpm_list[name] ,  metric_func , X , y , 5 , 5 ) 
        result_list[name] = [test_fold_index , oof, model_list]
        auc_score_list[name] = roc_auc_score(np.where(y > y.mean() , 1 ,0 ) , np.argmax(oof.mean(axis = 0) , axis = 1))
    print('Test_Classification_TestFold Compelte')

# %%
data = load_iris()
X = data.data
y = data.target

xtrain , xtest , ytrain , ytest = train_test_split(X , y , test_size = 0.2 )

Test_Classification(xtrain , ytrain , xtest , 5,False)
Test_Classification_TestFold(X,y,5,5)

print('done')
# Out:
# xgb
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ** Test Fold 5 on Model : myXGBClassifier **
#
# * Test Fold 0 *
# Total Training Time : 0:00:00.474999  [h:m:s]
#
# * Test Fold 1 *
# Total Training Time : 0:00:00.322000  [h:m:s]
#
# * Test Fold 2 *
# Total Training Time : 0:00:00.305001  [h:m:s]
#
# * Test Fold 3 *
# Total Training Time : 0:00:00.312001  [h:m:s]
#
# * Test Fold 4 *
# Total Training Time : 0:00:00.348999  [h:m:s]
# lgb
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ** Test Fold 5 on Model : myLGBMClassifier **
#
# * Test Fold 0 *
# Total Training Time : 0:00:03.350017  [h:m:s]
#
# * Test Fold 1 *
# Total Training Time : 0:00:03.659985  [h:m:s]
#
# * Test Fold 2 *
# Total Training Time : 0:00:02.930016  [h:m:s]
#
# * Test Fold 3 *
# Total Training Time : 0:00:03.431016  [h:m:s]
#
# * Test Fold 4 *
# Total Training Time : 0:00:02.145000  [h:m:s]
# cat
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ** Test Fold 5 on Model : myCatBoostClassifier **
#
# * Test Fold 0 *
# Total Training Time : 0:00:39.999001  [h:m:s]
#
# * Test Fold 1 *
# Total Training Time : 0:00:41.349999  [h:m:s]
#
# * Test Fold 2 *
# Total Training Time : 0:00:59.778001  [h:m:s]
#
# * Test Fold 3 *
# Total Training Time : 0:00:36.776997  [h:m:s]
#
# * Test Fold 4 *
# Total Training Time : 0:00:38.762001  [h:m:s]
# rfc
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ** Test Fold 5 on Model : myRandomForestClassifier **
#
# * Test Fold 0 *
# Total Training Time : 0:00:01.653021  [h:m:s]
#
# * Test Fold 1 *
# Total Training Time : 0:00:01.642025  [h:m:s]
#
# * Test Fold 2 *
# Total Training Time : 0:00:01.639995  [h:m:s]
#
# * Test Fold 3 *
# Total Training Time : 0:00:01.633002  [h:m:s]
#
# * Test Fold 4 *
# Total Training Time : 0:00:01.633018  [h:m:s]
# svm
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ** Test Fold 5 on Model : mySVMClassifier **
#
# * Test Fold 0 *
# Total Training Time : 0:00:00.007000  [h:m:s]
#
# * Test Fold 1 *
# Total Training Time : 0:00:00.007014  [h:m:s]
#
# * Test Fold 2 *
# Total Training Time : 0:00:00.008000  [h:m:s]
#
# * Test Fold 3 *
# Total Training Time : 0:00:00.006987  [h:m:s]
#
# * Test Fold 4 *
# Total Training Time : 0:00:00.007012  [h:m:s]
# gpc
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ** Test Fold 5 on Model : myGPClassifier **
#
# * Test Fold 0 *
# Total Training Time : 0:00:01.287001  [h:m:s]
#
# * Test Fold 1 *
# Total Training Time : 0:00:00.114000  [h:m:s]
#
# * Test Fold 2 *
# Total Training Time : 0:00:00.116000  [h:m:s]
#
# * Test Fold 3 *
# Total Training Time : 0:00:00.103001  [h:m:s]
#
# * Test Fold 4 *
# Total Training Time : 0:00:00.119000  [h:m:s]
# lda
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ** Test Fold 5 on Model : myLDAClassifier **
#
# * Test Fold 0 *
# Total Training Time : 0:00:00.004999  [h:m:s]
#
# * Test Fold 1 *
# Total Training Time : 0:00:00.006002  [h:m:s]
#
# * Test Fold 2 *
# Total Training Time : 0:00:00.005999  [h:m:s]
#
# * Test Fold 3 *
# Total Training Time : 0:00:00.006000  [h:m:s]
#
# * Test Fold 4 *
# Total Training Time : 0:00:00.005003  [h:m:s]
# qda
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ** Test Fold 5 on Model : myQDAClassifier **
#
# * Test Fold 0 *
# Total Training Time : 0:00:00.005999  [h:m:s]
#
# * Test Fold 1 *
# Total Training Time : 0:00:00.005000  [h:m:s]
#
# * Test Fold 2 *
# Total Training Time : 0:00:00.005999  [h:m:s]
#
# * Test Fold 3 *
# Total Training Time : 0:00:00.005005  [h:m:s]
#
# * Test Fold 4 *
# Total Training Time : 0:00:00.003996  [h:m:s]
# Test_Classification_TestFold Compelte
# done
