# %%
import sys
sys.path.append(r'E:\01_PProj\ML_LIB')
# Out:
# C:\Users\TBI\Miniconda3\envs\gb\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %%
import Lib_sjw.training as tr
import Lib_sjw.model_interface as mi
import Lib_sjw.model_parmas as mp
import Lib_sjw.evaluator as ev
import Lib_sjw.classification_util as cu

# %%
from sklearn.datasets import fetch_california_housing , load_iris , load_breast_cancer
from sklearn.metrics import mean_squared_error , roc_auc_score , precision_score
from sklearn.model_selection import train_test_split
import numpy as np

from collections import OrderedDict

# %%
'''
1. 데이터 만들기
2. 모델 제너레이터 만들기 
3. 모델 생성 파라미터, 피팅 파라미터 만들기 
4. 성능평가 메트릭 정의하기 :  f : y , pred -> value
5. training_fixedTest 실행하기 
6. 유틸에 테스트 데이터에 대한 성능평가, 또는 저장 등을 하기 
'''

def Test_Regression_TestFold(verbose = True):
    data = fetch_california_housing()
    X = data.data
    y = data.target

    # name list 
    name_list = ['xgb',
                 'lgb',
                 'cat',
                 'rfc',
                 'elt',
                 'svm',
                 'gpc']
    # model_list , param_list , 
    model_list = OrderedDict()      
    model_list['xgb']  = mi.myXGBRegressor()
    model_list['lgb']  = mi.myLGBMRegressor()
    model_list['cat']  = mi.myCatBoostRegressor()
    model_list['rfc']  = mi.myRandomForestRegressor()
    model_list['elt']  = mi.myElasticNetRegressor()
    model_list['svm']  = mi.mySVMRegressor()
    model_list['gpc']  = mi.myGPRegressor() 

    param_list = OrderedDict()
    param_list['xgb'] = mp.param_xgb('regression' , use_gpu= False)
    param_list['lgb'] = mp.param_lgbm('regression' , use_gpu= False)
    param_list['cat']  = mp.param_cat('regression' , use_gpu= True , is_unbalance= False )
    param_list['rfc']  = mp.param_rf('regression')
    param_list['elt']  = mp.param_elst('regression')
    param_list['svm']  = mp.param_svm('regression')
    param_list['gpc']  = mp.param_gpc('regression')    
    #fitting parmas
    fitpm_list = OrderedDict()

    for name in name_list:
            fitpm_list[name] = {}
    fitpm_list['lgb'] = {'early_stopping_rounds' : 12 , 'verbose' : -1}
    
    # metric func
    metric_func = mean_squared_error

    auc_score_list = OrderedDict()
    result_list = OrderedDict()
    for name in name_list:
        print(name)
        print('Model : {}'.format(name))
        test_fold_index , predictions , test_fold_models = tr.training_Testfold('regression' , model_list[name] , param_list[name] , fitpm_list[name] ,  metric_func , X , y , 5 , 5 ) 
        result_list[name] = [test_fold_index , predictions, test_fold_models] # 모든 데이터에 대해 예측값이 oof에 저장되어 있다. 
        auc_score_list[name] = roc_auc_score(np.where(y > 25 , 1 ,0 ) , predictions.mean(axis = 1))
    print('Test_Regression_TestFold Complete')

def Test_Regression():
    data = fetch_california_housing()
    X = data.data
    y = data.target
    
    xtrain , xtest , ytrain , ytest = train_test_split(X , y , test_size = 0.2 )

    # name list 
    name_list = ['xgb',
                 'lgb',
                 'cat',
                 'rfc',
                 'elt',
                 'svm',
                 'gpc']
    # model_list , param_list , 
    model_list = OrderedDict()      
    model_list['xgb']  = mi.myXGBRegressor()
    model_list['lgb']  = mi.myLGBMRegressor()
    model_list['cat']  = mi.myCatBoostRegressor()
    model_list['rfc']  = mi.myRandomForestRegressor()
    model_list['elt']  = mi.myElasticNetRegressor()
    model_list['svm']  = mi.mySVMRegressor()
    model_list['gpc']  = mi.myGPRegressor() 
    
    param_list = OrderedDict()
    param_list['xgb'] = mp.param_xgb('regression' , use_gpu= False)
    param_list['lgb'] = mp.param_lgbm('regression' , use_gpu= False)
    param_list['cat']  = mp.param_cat('regression' , use_gpu= True , is_unbalance= False )
    param_list['rfc']  = mp.param_rf('regression')
    param_list['elt']  = mp.param_elst('regression')
    param_list['svm']  = mp.param_svm('regression')
    param_list['gpc']  = mp.param_gpc('regression')    
    #fitting parmas
    fitpm_list = OrderedDict()
    for name in name_list:
            fitpm_list[name] = {}
    fitpm_list['lgb'] = {'early_stopping_rounds' : 12 , 'verbose' : -1}
    
    # metric func
    metric_func = mean_squared_error
    result_list = OrderedDict()   
    for name in name_list:
        print(name)
        fold_predict , fold_oof , fold_metric , fold_models = tr.training_fixedTest('regression' , model_list[name] , param_list[name] , fitpm_list[name] ,  metric_func , xtrain , ytrain , xtest , 5  ) 
        result_list[name] = [fold_predict , fold_oof , fold_metric , fold_models]
    print('Test_Regression Complete')

# %%
Test_Regression() # done 20180830
Test_Regression_TestFold(False)
print('done')
# Out:
# xgb
# Total Training Time : 0:00:01.273013  [h:m:s]
# lgb
# Total Training Time : 0:00:01.247985  [h:m:s]
# cat
# Total Training Time : 0:00:34.813000  [h:m:s]
# rfc
# Total Training Time : 0:00:01.635021  [h:m:s]
# elt
# Total Training Time : 0:00:00.003994  [h:m:s]
# svm
# Total Training Time : 0:00:00.039999  [h:m:s]
# gpc
# Total Training Time : 0:00:00.307986  [h:m:s]
# Test_Regression Complete
# xgb
# Model : xgb
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ** Test Fold 5 on Model : myXGBRegressor **
#
# * Test Fold 0 *
# Total Training Time : 0:00:01.138000  [h:m:s]
#
# * Test Fold 1 *
# Total Training Time : 0:00:01.235998  [h:m:s]
#
# * Test Fold 2 *
# Total Training Time : 0:00:01.123014  [h:m:s]
#
# * Test Fold 3 *
# Total Training Time : 0:00:01.165987  [h:m:s]
#
# * Test Fold 4 *
# Total Training Time : 0:00:01.201015  [h:m:s]
# lgb
# Model : lgb
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ** Test Fold 5 on Model : myLGBMRegressor **
#
# * Test Fold 0 *
# Total Training Time : 0:00:01.554989  [h:m:s]
#
# * Test Fold 1 *
# Total Training Time : 0:00:01.188012  [h:m:s]
#
# * Test Fold 2 *
# Total Training Time : 0:00:01.219999  [h:m:s]
#
# * Test Fold 3 *
# Total Training Time : 0:00:00.876991  [h:m:s]
#
# * Test Fold 4 *
# Total Training Time : 0:00:00.901010  [h:m:s]
# cat
# Model : cat
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ** Test Fold 5 on Model : myCatBoostRegressor **
#
# * Test Fold 0 *
# Total Training Time : 0:00:27.016999  [h:m:s]
#
# * Test Fold 1 *
# Total Training Time : 0:00:49.912001  [h:m:s]
#
# * Test Fold 2 *
# Total Training Time : 0:00:33.384998  [h:m:s]
#
# * Test Fold 3 *
# Total Training Time : 0:00:44.120998  [h:m:s]
#
# * Test Fold 4 *
# Total Training Time : 0:00:28.371985  [h:m:s]
# rfc
# Model : rfc
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ** Test Fold 5 on Model : myRandomForestRegressor **
#
# * Test Fold 0 *
# Total Training Time : 0:00:01.633017  [h:m:s]
#
# * Test Fold 1 *
# Total Training Time : 0:00:01.625982  [h:m:s]
#
# * Test Fold 2 *
# Total Training Time : 0:00:01.629012  [h:m:s]
#
# * Test Fold 3 *
# Total Training Time : 0:00:01.629007  [h:m:s]
#
# * Test Fold 4 *
# Total Training Time : 0:00:01.633998  [h:m:s]
# elt
# Model : elt
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ** Test Fold 5 on Model : myElasticNetRegressor **
#
# * Test Fold 0 *
# Total Training Time : 0:00:00.003000  [h:m:s]
#
# * Test Fold 1 *
# Total Training Time : 0:00:00.001996  [h:m:s]
#
# * Test Fold 2 *
# Total Training Time : 0:00:00.003000  [h:m:s]
#
# * Test Fold 3 *
# Total Training Time : 0:00:00.003000  [h:m:s]
#
# * Test Fold 4 *
# Total Training Time : 0:00:00.002012  [h:m:s]
# svm
# Model : svm
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ** Test Fold 5 on Model : mySVMRegressor **
#
# * Test Fold 0 *
# Total Training Time : 0:00:00.039002  [h:m:s]
#
# * Test Fold 1 *
# Total Training Time : 0:00:00.038011  [h:m:s]
#
# * Test Fold 2 *
# Total Training Time : 0:00:00.039000  [h:m:s]
#
# * Test Fold 3 *
# Total Training Time : 0:00:00.038000  [h:m:s]
#
# * Test Fold 4 *
# Total Training Time : 0:00:00.038013  [h:m:s]
# gpc
# Model : gpc
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ** Test Fold 5 on Model : myGPRegressor **
#
# * Test Fold 0 *
# Total Training Time : 0:00:00.439984  [h:m:s]
#
# * Test Fold 1 *
# Total Training Time : 0:00:00.389000  [h:m:s]
#
# * Test Fold 2 *
# Total Training Time : 0:00:00.377999  [h:m:s]
#
# * Test Fold 3 *
# Total Training Time : 0:00:00.557001  [h:m:s]
#
# * Test Fold 4 *
# Total Training Time : 0:00:00.333000  [h:m:s]
# Test_Regression_TestFold Complete
# done
